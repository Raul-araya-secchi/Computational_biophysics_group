# %% [markdown]
# ### Analyses for the PRLR paper ###

# %%
import sys 
import os 
import glob
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.gridspec as gridspec
import pandas as pd
import seaborn as sns
import fnmatch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec  # for unequal plot boxes
import scipy.optimize
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
import scipy
import scipy.stats
import matplotlib.ticker as ticker
import math
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
from pylab import *
from matplotlib.ticker import NullFormatter, MultipleLocator, FormatStrFormatter, FuncFormatter
from mpl_toolkits.axes_grid1 import make_axes_locatable
from gridData import Grid 
from io import StringIO
from collections import Counter
from scipy import stats
from scipy.stats import norm
from  scipy.stats import gaussian_kde
from sklearn.neighbors import KernelDensity
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from pylab import *
from matplotlib.ticker import NullFormatter
from matplotlib import font_manager

##

##Figure fonts and other params ##
hfont = {'fontname':'Helvetica'}
mpl.rcParams['figure.dpi'] =300
mpl.rcParams.update({'font.size': 16})
mpl.rcParams['pdf.fonttype'] = 42 
plt.rc('font', family='Helvetica')

# %% [markdown]
# # Aug-Sept 2020

# %% [markdown]
# # Figure 3

# %% [markdown]
# ###  Histograms of PLC from post_processed files w/o columns 1 and 2  --- CGm3pws10 minus first µs ###

# %% [markdown]
# #### BB - P04 contacts ####

# %%
from collections import Counter


plt.figure( figsize = (18,6)) 
##CGm3pws10_PCPS ##
plt.subplot(131)
dirs1 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*po4*PCPS_cgm3pws10_10us*dat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split() 
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([203, 301])

##CGm3pws10_PCPSPIP2 90:5:5 ##
plt.subplot(132)
dirs3 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*po4*955_cgm3pws10_10us*dat.dat'))
for num3, file in enumerate(dirs3):               
    #print(file)
    with open(file, 'r') as fd:
        lines3 = fd.read().split()  
    counter3 = Counter(lines3)
    items3 = sorted(counter3.items(), key=lambda x: int(x[0]))
    num_items3 = np.array(items3, dtype=int)
    print(num_items3)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(955) CGm3pws10 ')
    plt.bar((num_items3[:,0]+203), (num_items3[:,1]/9269))
    plt.ylim([0, 1])
    plt.xlim([203, 301])    
    
##CGm3pws10_PCPSPIP2 80:10:10 ##
plt.subplot(133)
dirs2 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*P*po4*_811_*cgm3pws10_r2*dat.dat'))
for num2, file in enumerate(dirs2):               
    #print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(811) CGm3pws10')
    plt.bar((num_items2[:,0]+203), (num_items2[:,1]/9964))
    plt.ylim([0, 1])
    plt.xlim([203, 301])
    
plt.tight_layout()  
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_PO4_mfus_correct.pdf", dpi=300)
plt.show()
# Out:
# [[   1  661]
#  [   2  532]
#  [   3  346]
#  [   4  386]
#  [   5  352]
#  [   6  578]
#  [   7  736]
#  [   8 1926]
#  [   9 3305]
#  [  10 1746]
#  [  11 1796]
#  [  12 2931]
#  [  13 3873]
#  [  14 2129]
#  [  15 2875]
#  [  16 1355]
#  [  17 1187]
#  [  18 2976]
#  [  19 1533]
#  [  20   49]
#  [  21  331]
#  [  22  405]
#  [  23   42]
#  [  24  152]
#  [  25  119]
#  [  26  183]
#  [  27 1829]
#  [  28 2951]
#  [  29 2615]
#  [  30 3629]
#  [  31 3261]
#  [  32 4293]
#  [  33 3513]
#  [  34 2691]
#  [  35 2510]
#  [  36 1660]
#  [  37 1470]
#  [  38 2221]
#  [  39 1832]
#  [  40 1415]
#  [  41 1526]
#  [  42 1581]
#  [  43 1672]
#  [  44 1820]
#  [  45 2138]
#  [  46 2124]
#  [  47 1519]
#  [  48  908]
#  [  49  403]
#  [  50  312]
#  [  51  188]
#  [  52  107]
#  [  53   48]
#  [  54   40]
#  [  55   22]
#  [  56    5]
#  [  57    4]
#  [  58    5]
#  [  59    9]
#  [  60    6]
#  [  61    3]
#  [  62    6]
#  [  63    1]
#  [  64    1]
#  [  66    1]
#  [  67    2]
# ...

# %% [markdown]
# #### BB - Acyl tail contacts
# #### Only beads: C1A D2A C3A C4A C1B C2B C3B C4B

# %%
from collections import Counter


plt.figure( figsize = (18,6)) 
##CGm3pws10_PCPS ##
plt.subplot(131)
dirs1 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*tail*PCPS_cgm3pws10_10us*dat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
        #lines1 = fd.read().split()  
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([203, 301])

##CGm3pws10_PCPSPIP2 90:5:5 ##
plt.subplot(132)
dirs3 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*tail*955_cgm3pws10_10us*dat.dat'))
for num3, file in enumerate(dirs3):               
    #print(file)
    with open(file, 'r') as fd:
        lines3 = fd.read().split()
    counter3 = Counter(lines3)
    items3 = sorted(counter3.items(), key=lambda x: int(x[0]))
    num_items3 = np.array(items3, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(955) CGm3pws10 ')
    #plt.bar((num_items3[:,0]+203), (num_items3[:,1]))
    plt.bar((num_items3[:,0]+203), (num_items3[:,1]/9269))
    plt.ylim([0, 1])
    plt.xlim([203, 301])    
    
##CGm3pws10_PCPSPIP2 80:10:10 ##
plt.subplot(133)
dirs2 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*tail*_811_*cgm3pws10*dat.dat'))
for num2, file in enumerate(dirs2):               
    #print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split() 
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(811) CGm3pws10')
    plt.bar((num_items2[:,0]+203), (num_items2[:,1]/9964))
    plt.ylim([0, 1])
    plt.xlim([203, 301])
    
plt.tight_layout()  
plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_deeptails_mfus_correct.pdf", dpi=300)
plt.show()

# %% [markdown]
# #### BB - HG contacts
# #### Not beads: PO4 GL1 GL2 C1A D2A C3A C4A C1B C2B C3B C4B

# %%
from collections import Counter


plt.figure( figsize = (18,6)) 
##CGm3pws10_PCPS ##
plt.subplot(131)
dirs1 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*HG*PCPS_cgm3pws10_10us*dat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
        #lines1 = fd.read().split()  
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([203, 301])

##CGm3pws10_PCPSPIP2 90:5:5 ##
plt.subplot(132)
dirs3 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*HG*955_cgm3pws10_10us*dat.dat'))
for num3, file in enumerate(dirs3):               
    #print(file)
    with open(file, 'r') as fd:
        lines3 = fd.read().split()
    counter3 = Counter(lines3)
    #print (counter3)
    items3 = sorted(counter3.items(), key=lambda x: int(x[0]))
    #print (items3)
    num_items3 = np.array(items3, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(955) CGm3pws10 ')
    plt.bar((num_items3[:,0]+203), (num_items3[:,1]/9269))
    #plt.bar((num_items3[:,0]+203), (num_items3[:,1]))
    plt.ylim([0, 1])
    plt.xlim([203, 301])    
    
##CGm3pws10_PCPSPIP2 80:10:10 ##
plt.subplot(133)
dirs2 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*HG*_811_*cgm3pws10*dat.dat'))
for num2, file in enumerate(dirs2):               
    #print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PCPSPIP2(811) CGm3pws10')
    plt.bar((num_items2[:,0]+203), (num_items2[:,1]/9964))
    plt.ylim([0, 1])
    plt.xlim([203, 301])
    
plt.tight_layout()  
plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %%
#PC Only #

from collections import Counter


plt.figure( figsize = (18,6)) 
##CGm3pws10_PCPS ##
plt.subplot(131)
dirs1 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*_PC*po4_PRLR_LID1_PC_*dat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()[999:]  
        #lines1 = fd.read().split()  
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PC CGm3pws10 PO4')
    plt.bar((num_items1[:,0]+203), (num_items1[:,1]/9807))
    plt.ylim([0, 1])
    plt.xlim([203, 301])

##CGm3pws10_PCPSPIP2 90:5:5 ##
plt.subplot(132)
dirs3 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*_PC*tail_PRLR_LID1_PC_*dat.dat'))
for num3, file in enumerate(dirs3):               
    #print(file)
    with open(file, 'r') as fd:
        #lines3 = fd.read().split()[999:]  
        lines3 = fd.read().split()  
        #print(lines3)
        #print (len(lines3))
    counter3 = Counter(lines3)
    items3 = sorted(counter3.items(), key=lambda x: int(x[0]))
    num_items3 = np.array(items3, dtype=int)
    #print(num_items3)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PC CGm3pws10 tails')
    plt.bar((num_items3[:,0]+203), (num_items3[:,1]/9807))
    plt.ylim([0, 1])
    plt.xlim([203, 301])    
    
##CGm3pws10_PCPSPIP2 80:10:10 ##
plt.subplot(133)
dirs2 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*_PC*HG_PRLR_LID1_PC_*dat.dat'))
for num2, file in enumerate(dirs2):               
    #print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    plt.title('PC CGm3pws10 HG')
    plt.bar((num_items2[:,0]+203), (num_items2[:,1]/9807))
    plt.ylim([0, 1])
    plt.xlim([203, 301])
    
plt.tight_layout()  
plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_PCpnly_po4_tails_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### PIP2_contact detail

# %%
from collections import Counter

plt.figure( figsize = (7,6)) 
##LID1_PCPSPIP2_811_ CGm3pws10, LID1_cgm2, LID1-2_cgm2  ##

file1 =('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/PLcontact_PIP2_HG_PRLR_LID1_PCPSPI2_811_cgm3pws10_r2.dat_hist.dat.dat')
file2 =('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/PLcontact_PIP2_tail_PRLR_LID1_PCPSPI2_811_cgm3pws10_r2.dat_hist.dat.dat')
    
with open(file1, 'r') as fd:
    lines1 = fd.read().split()        
          
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    
with open(file2, 'r') as fd:
    lines2 = fd.read().split()        
          
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    #plt.subplot(131)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+203), (num_items1[:,1]/9964), label ='HG')
    plt.bar((num_items2[:,0]+203), (num_items2[:,1]/9964), label ='tails', alpha=0.7)
    plt.legend( loc = 1, frameon = False, prop={'size': 10})
    plt.ylim([0, 1.0])
    plt.xlim([203, 301])
    
#plt.tight_layout()  
plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/for_NMRcomp_HG_tails_PCPSPIP2_811_bar.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Changes in PC binding profile -- HG, tails, PO4

# %%
plt.figure( figsize = (12,6)) 

plt.subplot(121)
dirs2 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*PIP2_HG*cgm3pws10*dat.dat'))
for num2, file in enumerate(dirs2):               
    #print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPSPIP2(811) CGm3pws10')
    plt.plot((num_items2[:,0]+203), (num_items2[:,1]))
    plt.ylim([0, 10000])
    plt.xlim([203, 301])
    
plt.subplot(122)
dirs3 = sorted(glob.glob('/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/histogram/*PIP2_tail*cgm3pws10*dat.dat'))
for num3, file in enumerate(dirs3):               
    #print(file)
    with open(file, 'r') as fd:
        lines3 = fd.read().split()
    counter3 = Counter(lines3)
    items3 = sorted(counter3.items(), key=lambda x: int(x[0]))
    num_items3 = np.array(items3, dtype=int)
    
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPSPIP2(811) CGm3pws10')
    plt.plot((num_items3[:,0]+203), (num_items3[:,1]))
    plt.ylim([0, 10000])
    plt.xlim([203, 301])    
    
plt.tight_layout()  
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### Lipid density maps for  LID1 sims

# %%
# Load maps #

## PIP2 Maps ##
PCPS = ("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/density/back_up/PRLR_LID1_PCPS_cgm3pws10_1ns_m1us_PSdens_po4.dx")
PIP_955 = ("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/density/back_up/PRLR_LID1_PCPSPI2_955_cgm3pws10_1ns_m1us_PIP2dens_po4.dx") 
PIP_811 = ("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/density/PRLR_LID1_PCPSPI2_811_cgm3pws10_r2_1ns_m1us_PIP2dens_po4.dx")

grid1=(Grid(PCPS))
#print (grid1)
grid2=(Grid(PIP_955))
grid3=(Grid(PIP_811))

# %%
# Plot maps #

norm1 = cm.colors.Normalize(vmax = 0.005)
norm2 = cm.colors.Normalize(vmax = 0.003)
norm3 = cm.colors.Normalize(vmax = 0.004)
#norm = cm.colors.LogNorm()

#normi = cm.colors.Normalize(vmin=0, vmax=0.005)

plt.figure(figsize = (18,6))

plt.subplot(131)
gridA = grid1.grid
sum_vecA = np.sum(gridA, axis=2)
rotA = np.rot90(sum_vecA)    
cfA = plt.contourf(rotA, 10, origin='upper', cmap = 'coolwarm', extend='neither',norm=norm1)
#plt.colorbar(cfA)
#plt.title(str(fname))   

plt.subplot(132)
gridB = grid2.grid
sum_vecB = np.sum(gridB, axis=2)
rotB = np.rot90(sum_vecB)    
cfB = plt.contourf(rotB, 10, origin='upper', cmap = 'coolwarm', extend='neither', norm=norm2)
#plt.colorbar(cfB)
#plt.title(str(fname))   

plt.subplot(133)
gridC = grid3.grid
sum_vecC = np.sum(gridC, axis=2)
rotC = np.rot90(sum_vecC)    
cfC = plt.contourf(rotC, 10, origin='upper', cmap = 'coolwarm', extend='neither',norm=norm3)
#plt.colorbar(cfC)
#plt.title(str(fname))   

plt.tight_layout()    
#plt.colorbar(cf)

#plt.colorbar(cax=cax)
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PRLR_LID_PS_PIP2_dens_m1us_m3pws10_Aug2020_norm_noCB.pdf", dpi=300)
plt.show()

# %% [markdown]
# ## MSD -- Diff. coeff. protein/TMD

# %% [markdown]
# # Figure 4

# %% [markdown]
# ## JAK2-PRLR LID1 AA sim --- contact map

# %% [markdown]
# ## JAK2-PRLR LID1 + PCPSPIP2 CG --- PLC profiles

# %% [markdown]
# ### Combined profile (1 -16)

# %%
## Fraction of total sim time 
from collections import Counter

plt.figure( figsize = (12,12)) 

## Tails ## JAK2 ##
plt.subplot(221)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/J*_tail_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/160592))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## Tails ## LID1  ##    
    
plt.subplot(222)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/L*_tail_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/160592))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/160576))
    plt.ylim([0, 1])
    plt.xlim([234, 285])
    
## HG ## JAK2  ##   
    
plt.subplot(223)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/J*_hg_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/160592))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## HG ## LID1  ##    
    
plt.subplot(224)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/L*_hg_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/160592))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([234, 285])    


    
plt.tight_layout()  
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %%
## Frac. contact time 
from collections import Counter

plt.figure( figsize = (12,12)) 

## Tails ## JAK2 ##
plt.subplot(221)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/J*_tail_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/145495))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## Tails ## LID1  ##    
    
plt.subplot(222)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/L*_tail_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/145495))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/160576))
    plt.ylim([0, 1])
    plt.xlim([234, 285])
    
## HG ## JAK2  ##   
    
plt.subplot(223)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/J*_hg_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/145495))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## HG ## LID1  ##    
    
plt.subplot(224)
dirs1 = sorted(glob.glob('/home/raul/remote-home/remote-home/MD-sims/JAK2-FERM-SH2_LID1_CG/PCPSPIP2/results/PLC/L*_hg_cat.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/145495))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([234, 285])    


    
plt.tight_layout()  
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %% [markdown]
# ### JAK2 - LID1 PCPS

# %%
## Fraction of contact time
from collections import Counter

plt.figure( figsize = (12,12)) 

## Tails ## JAK2 ##
plt.subplot(221)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/J*tail*.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## Tails ## LID1  ##    
    
plt.subplot(222)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/L*tail*.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/160576))
    plt.ylim([0, 1])
    plt.xlim([234, 285])
    
## HG ## JAK2  ##   
    
plt.subplot(223)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/J*hg*.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]), (num_items1[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([1, 479])
    
## HG ## LID1  ##    
    
plt.subplot(224)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/L*hg*.dat'))
for num1, file in enumerate(dirs1):               
    #print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]-244), (num_items1[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([234, 285])    

plt.tight_layout()  
#plt.savefig("/home/raul/projects/MD-runs/synergy/SPTMRs/PRLR/CG/results/PLC/Aug2020/figs/PRLR_LID_cgm3pws10_PLC_his_HG_mfus_correct.pdf", dpi=300)
plt.show()

# %%
## Fraction of contact time
from collections import Counter

plt.figure( figsize = (12,6)) 

## Tails ## JAK2 ##
plt.subplot(121)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/J*.dat'))
for num1, file in enumerate(dirs1):               
    print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+36), (num_items1[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([37, 515])
for line in num_items1:
    print(*line)
## Tails ## LID1  ##    
    
plt.subplot(122)
dirs2 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/L*.dat'))
for num2, file in enumerate(dirs2):               
    print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of sim. time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items2[:,0]-244), (num_items2[:,1]/8525))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/160576))
    plt.ylim([0, 1])
    plt.xlim([234, 285])
    

plt.tight_layout()  
plt.savefig("/home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/figs_PRLR_JAK2_CGm22_PCPS_PLC.pdf", dpi=300)
plt.show()
# Out:
# /home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/JPC_JAK2-fermsh2-LID1_PCPS_C1.dat
# /home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/JPS_JAK2-fermsh2-LID1_PCPS_C1.dat
# 92 3
# 132 6
# 133 336
# 134 744
# 135 3757
# 136 3322
# 137 462
# 138 18
# 139 305
# 140 238
# 141 2
# 143 4
# 144 1
# 162 4
# 163 3
# 165 7
# 166 37
# 167 5
# 168 2
# 177 42
# 178 80
# 179 23
# 180 89
# 181 540
# 182 1170
# 183 2156
# 184 2777
# 185 5008
# 186 6337
# 187 7625
# 188 7560
# 189 5093
# 190 5777
# 191 6185
# 192 1837
# 193 2164
# 194 3879
# 195 499
# 196 436
# 197 10
# 198 156
# 199 295
# 200 11
# 201 4
# 202 106
# 203 106
# 204 1
# 205 4
# 206 2
# 224 1
# 225 1
# 243 5
# 244 25
# 245 32
# 246 20
# 247 6
# 248 3
# 265 1
# 266 92
# 267 232
# 268 315
# 269 154
# 270 69
# 271 23
# 272 7
# 273 9
# 274 66
# 275 26
# 276 3
# 277 5
# 297 1
# 298 2
# 299 4
# 300 4
# 301 3
# 302 1
# /home/raul/projects/PRLR_MS_2022/PRLR_JAK2_CGm22_PCPS/LPC_JAK2-fermsh2-LID1_PCPS_C1.dat
# ...

# %%
from collections import Counter

plt.figure( figsize = (12,12)) 

## Tails ## JAK2 ##
plt.subplot(221)
dirs1 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/J*C3*.dat'))
for num1, file in enumerate(dirs1):               
    print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of contact time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+36), (num_items1[:,1]/9687))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([37, 515])

plt.subplot(222)    
dirs2 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/J*C9_S2*.dat'))
for num2, file in enumerate(dirs2):               
    print(file)
    with open(file, 'r') as fd:
        lines2 = fd.read().split()
    counter2 = Counter(lines2)
    items2 = sorted(counter2.items(), key=lambda x: int(x[0]))
    num_items2 = np.array(items2, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of contact time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items2[:,0]+36), (num_items2[:,1]/4390))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([37, 515])

plt.subplot(223)
dirs3 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/J*C6*.dat'))
for num1, file in enumerate(dirs3):               
    print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of contact time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+36), (num_items1[:,1]/2495))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([37, 515])
    

plt.subplot(224)
dirs3 = sorted(glob.glob('/home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/J*C1_S2*.dat'))
for num1, file in enumerate(dirs3):               
    print(file)
    with open(file, 'r') as fd:
        lines1 = fd.read().split()
    counter1 = Counter(lines1)
    items1 = sorted(counter1.items(), key=lambda x: int(x[0]))
    num_items1 = np.array(items1, dtype=int)
    #print(num_items1)
    plt.xlabel('Residue number')
    plt.ylabel('Fraction of contact time')
    #plt.title('PCPS(70:30) CGm3pws10')
    plt.bar((num_items1[:,0]+36), (num_items1[:,1]/9975))
    #plt.bar((num_items1[:,0]+203), (num_items1[:,1]/8658))
    plt.ylim([0, 1])
    plt.xlim([36, 515])

plt.tight_layout()  
plt.savefig("/home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/figs_JAK2_CGm22_PCPSPIP2_C3_C9_C6_C1_PLC.pdf", dpi=300)
plt.show()
# Out:
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JP2_JAK_FERM_noLID_PCPSPIP2_C3_S1.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPC_JAK_FERM_noLID_PCPSPIP2_C3_S1.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPS_JAK_FERM_noLID_PCPSPIP2_C3_S1.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JP2_JAK_FERM_noLID_PCPSPIP2_C9_S2_plus.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPC_JAK_FERM_noLID_PCPSPIP2_C9_S2_plus.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPS_JAK_FERM_noLID_PCPSPIP2_C9_S2_plus.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JP2_JAK_FERM_noLID_PCPSPIP2_C6_S3.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPC_JAK_FERM_noLID_PCPSPIP2_C6_S3.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JPS_JAK_FERM_noLID_PCPSPIP2_C6_S3.dat
# /home/raul/projects/PRLR_MS_2022/JAK2_CGM2_PCPSPIP2/JP2_JAK_FERM_noLID_PCPSPIP2_C1_S2.dat
# ...
